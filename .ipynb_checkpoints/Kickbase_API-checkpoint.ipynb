# %%
import pandas as pd
from datetime import datetime
from kickbase_api.kickbase import Kickbase
import os

# %%
kickbase = Kickbase()
user, leagues = kickbase.login("fibi.mayr@gmail.com", "bYmtev-0qarcu-gykwij")

# %%
datetime = datetime.now()
dt_string = datetime.strftime("%d.%m.%Y %H:%M:%S")
# Out:
# '25.07.2022 13:44:19'

# %%
players = {
    "first_name":[],
    "last_name":[],
    "id":[],
    "market_value":[],
    "market_value_trend":[],
    "team_id":[],
    "date":[]
    }

for team_id in range(100):
    try:
        team_players = kickbase.team_players(str(team_id))
        for player in team_players:
            players["first_name"].append(player.first_name)
            players["last_name"].append(player.last_name)
            players["id"].append(player.id)
            players["market_value"].append(player.market_value)
            players["market_value_trend"].append(player.market_value_trend)
            players["team_id"].append(player.team_id)
            players["date"].append(dt_string)
    except:
        pass

# %%
players_df = pd.DataFrame(players)
players_df.sample(10)
# Out:
#         first_name  last_name    id  market_value  market_value_trend team_id  \
# 1148         Edgar      Badia  3876    15225000.0                   1      62
# 837          Janis   Blaswich     4      500000.0                   0      43
# 102          Lucas      Höler  2176    19255881.0                   2       5
# 1147         Pedro      Bigas  3875    10355000.0                   1      62
# 190         Marvin  Pieringer  3027     2882415.0                   1       8
# 1086       Antonio    Rüdiger    23    25745112.0                   1      58
# 205         Maxime    Awoudja  2130     3741407.0                   1       9
# 584   Ryan Patrick     Malone  3446     8062116.0                   1      23
# 445       Jonathan   Burkardt  2255    20921352.0                   1      18
# 407           Carl      Klaus  3364      500000.0                   2      16
#
#                      date
# 1148  25.07.2022 13:44:19
# 837   25.07.2022 13:44:19
# 102   25.07.2022 13:44:19
# 1147  25.07.2022 13:44:19
# 190   25.07.2022 13:44:19
# 1086  25.07.2022 13:44:19
# 205   25.07.2022 13:44:19
# 584   25.07.2022 13:44:19
# 445   25.07.2022 13:44:19
# 407   25.07.2022 13:44:19

# %%
players_df["date"] = players_df["date"].apply(lambda x: x.replace("26.", "27."))
players_df["market_value"] = players_df["market_value"] + 20000

# %%
if "player_data.csv" in os.listdir():
    history_df = pd.read_csv("player_data.csv")
    players_df = pd.concat([history_df, players_df], ignore_index=True)

players_df = players_df.drop_duplicates(subset=["first_name", "last_name", "date"], keep="first")
    
players_df.to_csv("player_data.csv", index=False)

# %%
players_df[players_df["last_name"] == "Pululu"]
# Out:
#      first_name last_name    id  market_value  market_value_trend team_id  \
# 482     Afimico    Pululu  3174     2344223.0                   2      19
# 1934    Afimico    Pululu  3174     2354223.0                   2      19
# 4838    Afimico    Pululu  3174     2374223.0                   2      19
#
#                      date
# 482   25.07.2022 13:44:19
# 1934  26.07.2022 13:44:19
# 4838  27.07.2022 13:44:19
